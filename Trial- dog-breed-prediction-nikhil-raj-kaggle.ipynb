# %% [markdown]
# ## Dog Breed Prediction

# %% [markdown]
# In this project, we will see how to use Keras and TensorFlow to build, train, and test a Convolutional Neural Network capable of identifying the breed of a dog in a supplied image. This is a supervised learning problem, specifically a multiclass classification problem.

# %%
# Important library imports
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt

from tqdm import tqdm
from keras.preprocessing import image
from sklearn.preprocessing import label_binarize
from sklearn.model_selection import train_test_split
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPool2D
from tensorflow.keras.optimizers import Adam

# %% [markdown]
# Importing required libraries.

# %%
# Read the labels.csv file and checking shape and records
labels_all = pd.read_csv("../input/dogbreedidfromcomp/labels.csv")
print(labels_all.shape)
labels_all.head()
# Out:
# (10222, 2)
#                                  id             breed
# 0  000bec180eb18c7604dcecc8fe0dba07       boston_bull
# 1  001513dfcb2ffafc82cccf4d8bbaba97             dingo
# 2  001cdf01b096e06d78e9e5112d419397          pekinese
# 3  00214f311d5d2247d5dfe4fe24b2303d          bluetick
# 4  0021f9ceb3235effd7fcde7f7538ed62  golden_retriever

# %% [markdown]
# Loading the labels data into dataframe and viewing it. Here we analysed that labels contains 10222 rows and 2 columns.

# %%
# Visualize the number of each breeds
breeds_all = labels_all["breed"]
breed_counts = breeds_all.value_counts()
breed_counts.head()
# Out:
# scottish_deerhound      126
# maltese_dog             117
# afghan_hound            116
# entlebucher             115
# bernese_mountain_dog    114
# Name: breed, dtype: int64

# %% [markdown]
# Here we are finding out the count per class i.e. total data in each class using value_counts() function.

# %%
# Selecting first 3 breeds (Limitation due to computation power)
CLASS_NAMES = ['scottish_deerhound','maltese_dog','bernese_mountain_dog']
labels = labels_all[(labels_all['breed'].isin(CLASS_NAMES))]
labels = labels.reset_index()
labels.head()
# Out:
#    index                                id                 breed
# 0      9  0042188c895a2f14ef64a918ed9c7b64    scottish_deerhound
# 1     12  00693b8bc2470375cc744a6391d397ec           maltese_dog
# 2     79  01e787576c003930f96c966f9c3e1d44    scottish_deerhound
# 3     90  022b34fd8734b39995a9f38a4f3e7b6b           maltese_dog
# 4    118  02d54f0dfb40038765e838459ae8c956  bernese_mountain_dog

# %% [markdown]
# We will work on only 3 breeds due to limited computational power. You can consider more classes as per your system computational power.

# %%
# Creating numpy matrix with zeros
X_data = np.zeros((len(labels), 224, 224, 3), dtype='float32')
# One hot encoding
Y_data = label_binarize(labels['breed'], classes = CLASS_NAMES)

# Reading and converting image to numpy array and normalizing dataset
for i in tqdm(range(len(labels))):
    img = image.load_img('../input/dogbreedidfromcomp/train/%s.jpg' % labels['id'][i], target_size=(224, 224))
    img = image.img_to_array(img)
    x = np.expand_dims(img.copy(), axis=0)
    X_data[i] = x / 255.0
    
# Printing train image and one hot encode shape & size
print('\nTrain Images shape: ',X_data.shape,' size: {:,}'.format(X_data.size))
print('One-hot encoded output shape: ',Y_data.shape,' size: {:,}'.format(Y_data.size))
# Out:
# 100%|██████████| 357/357 [00:01<00:00, 217.52it/s]
# Train Images shape:  (357, 224, 224, 3)  size: 53,738,496
# One-hot encoded output shape:  (357, 3)  size: 1,071

# %% [markdown]
# As we are working with the classification dataset first we need to one hot encode the target value i.e. the classes. After that we will read images and convert them into numpy array and finally normalizing the array.

# %%
# Building the Model
model = Sequential()

model.add(Conv2D(filters = 64, kernel_size = (5,5), activation ='relu', input_shape = (224,224,3)))
model.add(MaxPool2D(pool_size=(2,2)))

model.add(Conv2D(filters = 32, kernel_size = (3,3), activation ='relu', kernel_regularizer = 'l2'))
model.add(MaxPool2D(pool_size=(2,2)))

model.add(Conv2D(filters = 16, kernel_size = (7,7), activation ='relu', kernel_regularizer = 'l2'))
model.add(MaxPool2D(pool_size=(2,2)))

model.add(Conv2D(filters = 8, kernel_size = (5,5), activation ='relu', kernel_regularizer = 'l2'))
model.add(MaxPool2D(pool_size=(2,2)))

model.add(Flatten())
model.add(Dense(128, activation = "relu", kernel_regularizer = 'l2'))
model.add(Dense(64, activation = "relu", kernel_regularizer = 'l2'))
model.add(Dense(len(CLASS_NAMES), activation = "softmax"))

model.compile(loss = 'categorical_crossentropy', optimizer = Adam(0.0001),metrics=['accuracy'])

model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_8 (Conv2D)            (None, 220, 220, 64)      4864
# _________________________________________________________________
# max_pooling2d_8 (MaxPooling2 (None, 110, 110, 64)      0
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 108, 108, 32)      18464
# _________________________________________________________________
# max_pooling2d_9 (MaxPooling2 (None, 54, 54, 32)        0
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 48, 48, 16)        25104
# _________________________________________________________________
# max_pooling2d_10 (MaxPooling (None, 24, 24, 16)        0
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 20, 20, 8)         3208
# _________________________________________________________________
# max_pooling2d_11 (MaxPooling (None, 10, 10, 8)         0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 800)               0
# _________________________________________________________________
# dense_6 (Dense)              (None, 128)               102528
# _________________________________________________________________
# dense_7 (Dense)              (None, 64)                8256
# _________________________________________________________________
# dense_8 (Dense)              (None, 3)                 195
# =================================================================
# Total params: 162,619
# Trainable params: 162,619
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# Next we will create a network architecture for the model. We have used different types of layers according to their features namely Conv_2d (It is used to create a convolutional kernel that is convolved with the input layer to produce the output tensor), max_pooling2d (It is a downsampling technique which takes out the maximum value over the window defined by poolsize), flatten (It flattens the input and creates a 1D output), Dense (Dense layer produce the output as the dot product of input and kernel).

# %% [markdown]
# After defining the network architecture we found out the total parameters as 162,619.

# %%
# Splitting the data set into training and testing data sets
X_train_and_val, X_test, Y_train_and_val, Y_test = train_test_split(X_data, Y_data, test_size = 0.1)
# Splitting the training data set into training and validation data sets
X_train, X_val, Y_train, Y_val = train_test_split(X_train_and_val, Y_train_and_val, test_size = 0.2)

# %% [markdown]
# After defining the network architecture we will start with splitting the test and train data then dividing train data in train and validation data.

# %%
# Training the model
epochs = 100
batch_size = 128

history = model.fit(X_train, Y_train, batch_size = batch_size, epochs = epochs, 
                    validation_data = (X_val, Y_val))
# Out:
# Epoch 1/100
# 2/2 [==============================] - 11s 5s/step - loss: 4.9084 - accuracy: 0.3008 - val_loss: 4.8860 - val_accuracy: 0.3077
# Epoch 2/100
# 2/2 [==============================] - 9s 5s/step - loss: 4.8801 - accuracy: 0.3164 - val_loss: 4.8624 - val_accuracy: 0.3077
# Epoch 3/100
# 2/2 [==============================] - 10s 5s/step - loss: 4.8552 - accuracy: 0.3281 - val_loss: 4.8372 - val_accuracy: 0.3385
# Epoch 4/100
# 2/2 [==============================] - 9s 5s/step - loss: 4.8297 - accuracy: 0.3945 - val_loss: 4.8129 - val_accuracy: 0.4308
# Epoch 5/100
# 2/2 [==============================] - 10s 5s/step - loss: 4.8045 - accuracy: 0.5000 - val_loss: 4.7878 - val_accuracy: 0.4923
# Epoch 6/100
# 2/2 [==============================] - 9s 5s/step - loss: 4.7792 - accuracy: 0.5703 - val_loss: 4.7620 - val_accuracy: 0.5846
# Epoch 7/100
# 2/2 [==============================] - 10s 5s/step - loss: 4.7528 - accuracy: 0.6055 - val_loss: 4.7346 - val_accuracy: 0.5692
# Epoch 8/100
# 2/2 [==============================] - 9s 5s/step - loss: 4.7261 - accuracy: 0.6250 - val_loss: 4.7075 - val_accuracy: 0.6000
# Epoch 9/100
# 2/2 [==============================] - 9s 5s/step - loss: 4.7002 - accuracy: 0.6016 - val_loss: 4.6811 - val_accuracy: 0.5692
# Epoch 10/100
# 2/2 [==============================] - 10s 5s/step - loss: 4.6731 - accuracy: 0.5859 - val_loss: 4.6533 - val_accuracy: 0.6000
# Epoch 11/100
# 2/2 [==============================] - 9s 5s/step - loss: 4.6446 - accuracy: 0.5742 - val_loss: 4.6253 - val_accuracy: 0.5846
# Epoch 12/100
# 2/2 [==============================] - 9s 5s/step - loss: 4.6164 - accuracy: 0.5742 - val_loss: 4.5960 - val_accuracy: 0.6000
# Epoch 13/100
# 2/2 [==============================] - 9s 5s/step - loss: 4.5860 - accuracy: 0.5586 - val_loss: 4.5674 - val_accuracy: 0.5692
# Epoch 14/100
# 2/2 [==============================] - 10s 5s/step - loss: 4.5549 - accuracy: 0.5625 - val_loss: 4.5316 - val_accuracy: 0.5846
# Epoch 15/100
# 2/2 [==============================] - 9s 5s/step - loss: 4.5224 - accuracy: 0.5938 - val_loss: 4.4940 - val_accuracy: 0.6000
# Epoch 16/100
# 2/2 [==============================] - 9s 5s/step - loss: 4.4883 - accuracy: 0.6016 - val_loss: 4.4604 - val_accuracy: 0.6154
# Epoch 17/100
# 2/2 [==============================] - 10s 5s/step - loss: 4.4532 - accuracy: 0.6133 - val_loss: 4.4236 - val_accuracy: 0.6462
# Epoch 18/100
# 2/2 [==============================] - 10s 5s/step - loss: 4.4151 - accuracy: 0.6367 - val_loss: 4.3815 - val_accuracy: 0.6615
# Epoch 19/100
# 2/2 [==============================] - 9s 5s/step - loss: 4.3773 - accuracy: 0.6367 - val_loss: 4.3388 - val_accuracy: 0.6615
# Epoch 20/100
# 2/2 [==============================] - 10s 5s/step - loss: 4.3358 - accuracy: 0.6523 - val_loss: 4.2991 - val_accuracy: 0.6769
# Epoch 21/100
# 2/2 [==============================] - 10s 5s/step - loss: 4.2911 - accuracy: 0.6562 - val_loss: 4.2481 - val_accuracy: 0.6923
# Epoch 22/100
# 2/2 [==============================] - 9s 5s/step - loss: 4.2487 - accuracy: 0.6719 - val_loss: 4.2019 - val_accuracy: 0.7231
# Epoch 23/100
# 2/2 [==============================] - 9s 5s/step - loss: 4.1959 - accuracy: 0.7305 - val_loss: 4.1573 - val_accuracy: 0.6923
# Epoch 24/100
# 2/2 [==============================] - 10s 5s/step - loss: 4.1534 - accuracy: 0.7188 - val_loss: 4.1065 - val_accuracy: 0.7077
# Epoch 25/100
# 2/2 [==============================] - 9s 5s/step - loss: 4.1047 - accuracy: 0.7227 - val_loss: 4.0626 - val_accuracy: 0.7077
# Epoch 26/100
# 2/2 [==============================] - 9s 5s/step - loss: 4.0596 - accuracy: 0.7422 - val_loss: 4.0303 - val_accuracy: 0.7077
# Epoch 27/100
# 2/2 [==============================] - 9s 5s/step - loss: 4.0139 - accuracy: 0.7578 - val_loss: 3.9819 - val_accuracy: 0.7385
# Epoch 28/100
# 2/2 [==============================] - 10s 5s/step - loss: 3.9674 - accuracy: 0.7695 - val_loss: 3.9535 - val_accuracy: 0.6923
# Epoch 29/100
# 2/2 [==============================] - 9s 5s/step - loss: 3.9261 - accuracy: 0.7656 - val_loss: 3.9130 - val_accuracy: 0.7077
# Epoch 30/100
# 2/2 [==============================] - 9s 5s/step - loss: 3.8954 - accuracy: 0.7695 - val_loss: 3.8897 - val_accuracy: 0.6923
# Epoch 31/100
# 2/2 [==============================] - 10s 5s/step - loss: 3.8575 - accuracy: 0.7852 - val_loss: 3.8467 - val_accuracy: 0.7385
# Epoch 32/100
# 2/2 [==============================] - 9s 5s/step - loss: 3.8212 - accuracy: 0.7891 - val_loss: 3.8209 - val_accuracy: 0.7538
# Epoch 33/100
# 2/2 [==============================] - 9s 5s/step - loss: 3.8102 - accuracy: 0.7656 - val_loss: 3.7985 - val_accuracy: 0.7538
# Epoch 34/100
# 2/2 [==============================] - 9s 5s/step - loss: 3.7912 - accuracy: 0.7852 - val_loss: 3.7873 - val_accuracy: 0.7692
# Epoch 35/100
# 2/2 [==============================] - 10s 5s/step - loss: 3.7373 - accuracy: 0.8164 - val_loss: 3.7996 - val_accuracy: 0.6923
# Epoch 36/100
# 2/2 [==============================] - 9s 5s/step - loss: 3.7206 - accuracy: 0.8047 - val_loss: 3.7556 - val_accuracy: 0.7385
# Epoch 37/100
# 2/2 [==============================] - 9s 5s/step - loss: 3.7032 - accuracy: 0.8203 - val_loss: 3.7340 - val_accuracy: 0.7231
# Epoch 38/100
# 2/2 [==============================] - 10s 5s/step - loss: 3.6620 - accuracy: 0.8281 - val_loss: 3.7340 - val_accuracy: 0.7077
# Epoch 39/100
# 2/2 [==============================] - 9s 5s/step - loss: 3.6545 - accuracy: 0.8320 - val_loss: 3.6997 - val_accuracy: 0.7692
# Epoch 40/100
# 2/2 [==============================] - 9s 5s/step - loss: 3.6216 - accuracy: 0.8320 - val_loss: 3.6973 - val_accuracy: 0.7231
# Epoch 41/100
# 2/2 [==============================] - 9s 5s/step - loss: 3.6031 - accuracy: 0.8398 - val_loss: 3.6681 - val_accuracy: 0.7385
# Epoch 42/100
# 2/2 [==============================] - 10s 5s/step - loss: 3.5719 - accuracy: 0.8477 - val_loss: 3.6550 - val_accuracy: 0.7538
# Epoch 43/100
# 2/2 [==============================] - 9s 5s/step - loss: 3.5576 - accuracy: 0.8516 - val_loss: 3.6597 - val_accuracy: 0.7538
# Epoch 44/100
# 2/2 [==============================] - 9s 5s/step - loss: 3.5431 - accuracy: 0.8594 - val_loss: 3.6340 - val_accuracy: 0.7538
# Epoch 45/100
# 2/2 [==============================] - 10s 5s/step - loss: 3.5167 - accuracy: 0.8594 - val_loss: 3.6114 - val_accuracy: 0.7692
# Epoch 46/100
# 2/2 [==============================] - 9s 5s/step - loss: 3.5061 - accuracy: 0.8594 - val_loss: 3.6288 - val_accuracy: 0.7231
# Epoch 47/100
# 2/2 [==============================] - 9s 5s/step - loss: 3.5036 - accuracy: 0.8359 - val_loss: 3.6030 - val_accuracy: 0.7385
# Epoch 48/100
# 2/2 [==============================] - 9s 5s/step - loss: 3.4727 - accuracy: 0.8672 - val_loss: 3.5944 - val_accuracy: 0.7538
# Epoch 49/100
# 2/2 [==============================] - 10s 5s/step - loss: 3.4554 - accuracy: 0.8594 - val_loss: 3.6182 - val_accuracy: 0.7231
# Epoch 50/100
# 2/2 [==============================] - 9s 5s/step - loss: 3.4523 - accuracy: 0.8477 - val_loss: 3.5732 - val_accuracy: 0.7385
# Epoch 51/100
# 2/2 [==============================] - 9s 5s/step - loss: 3.4442 - accuracy: 0.8594 - val_loss: 3.5555 - val_accuracy: 0.7538
# Epoch 52/100
# 2/2 [==============================] - 9s 5s/step - loss: 3.4244 - accuracy: 0.8555 - val_loss: 3.6006 - val_accuracy: 0.7231
# Epoch 53/100
# 2/2 [==============================] - 10s 5s/step - loss: 3.4110 - accuracy: 0.8477 - val_loss: 3.5605 - val_accuracy: 0.7385
# Epoch 54/100
# 2/2 [==============================] - 9s 5s/step - loss: 3.4095 - accuracy: 0.8438 - val_loss: 3.5406 - val_accuracy: 0.7385
# Epoch 55/100
# 2/2 [==============================] - 9s 5s/step - loss: 3.3805 - accuracy: 0.8633 - val_loss: 3.5833 - val_accuracy: 0.7385
# Epoch 56/100
# 2/2 [==============================] - 10s 6s/step - loss: 3.3657 - accuracy: 0.8594 - val_loss: 3.5485 - val_accuracy: 0.7385
# Epoch 57/100
# 2/2 [==============================] - 9s 5s/step - loss: 3.3697 - accuracy: 0.8477 - val_loss: 3.5124 - val_accuracy: 0.7538
# Epoch 58/100
# 2/2 [==============================] - 9s 5s/step - loss: 3.3089 - accuracy: 0.8867 - val_loss: 3.5617 - val_accuracy: 0.7077
# Epoch 59/100
# 2/2 [==============================] - 9s 5s/step - loss: 3.3172 - accuracy: 0.8828 - val_loss: 3.4807 - val_accuracy: 0.7385
# Epoch 60/100
# 2/2 [==============================] - 9s 5s/step - loss: 3.3103 - accuracy: 0.8711 - val_loss: 3.4705 - val_accuracy: 0.7385
# Epoch 61/100
# 2/2 [==============================] - 9s 5s/step - loss: 3.2795 - accuracy: 0.8867 - val_loss: 3.5201 - val_accuracy: 0.7077
# Epoch 62/100
# 2/2 [==============================] - 9s 5s/step - loss: 3.2810 - accuracy: 0.8906 - val_loss: 3.4647 - val_accuracy: 0.7538
# Epoch 63/100
# 2/2 [==============================] - 10s 5s/step - loss: 3.2757 - accuracy: 0.8750 - val_loss: 3.4477 - val_accuracy: 0.7385
# Epoch 64/100
# 2/2 [==============================] - 9s 5s/step - loss: 3.2318 - accuracy: 0.8945 - val_loss: 3.4800 - val_accuracy: 0.7077
# Epoch 65/100
# 2/2 [==============================] - 9s 5s/step - loss: 3.2413 - accuracy: 0.8945 - val_loss: 3.4361 - val_accuracy: 0.7538
# Epoch 66/100
# 2/2 [==============================] - 9s 5s/step - loss: 3.2072 - accuracy: 0.9062 - val_loss: 3.4346 - val_accuracy: 0.7385
# Epoch 67/100
# 2/2 [==============================] - 10s 5s/step - loss: 3.2039 - accuracy: 0.8867 - val_loss: 3.4370 - val_accuracy: 0.7231
# Epoch 68/100
# 2/2 [==============================] - 9s 5s/step - loss: 3.1841 - accuracy: 0.9023 - val_loss: 3.4125 - val_accuracy: 0.7538
# Epoch 69/100
# 2/2 [==============================] - 9s 5s/step - loss: 3.1777 - accuracy: 0.8984 - val_loss: 3.3970 - val_accuracy: 0.7385
# Epoch 70/100
# 2/2 [==============================] - 10s 5s/step - loss: 3.1641 - accuracy: 0.9023 - val_loss: 3.4118 - val_accuracy: 0.7231
# Epoch 71/100
# 2/2 [==============================] - 9s 5s/step - loss: 3.1455 - accuracy: 0.9102 - val_loss: 3.3934 - val_accuracy: 0.7385
# Epoch 72/100
# 2/2 [==============================] - 9s 5s/step - loss: 3.1306 - accuracy: 0.9141 - val_loss: 3.3846 - val_accuracy: 0.7385
# Epoch 73/100
# 2/2 [==============================] - 9s 5s/step - loss: 3.1135 - accuracy: 0.9102 - val_loss: 3.3799 - val_accuracy: 0.7231
# Epoch 74/100
# 2/2 [==============================] - 10s 5s/step - loss: 3.1102 - accuracy: 0.9102 - val_loss: 3.3688 - val_accuracy: 0.7385
# Epoch 75/100
# 2/2 [==============================] - 9s 5s/step - loss: 3.0915 - accuracy: 0.9102 - val_loss: 3.3608 - val_accuracy: 0.7385
# Epoch 76/100
# 2/2 [==============================] - 9s 5s/step - loss: 3.0781 - accuracy: 0.9102 - val_loss: 3.3447 - val_accuracy: 0.7231
# Epoch 77/100
# 2/2 [==============================] - 10s 5s/step - loss: 3.0673 - accuracy: 0.9102 - val_loss: 3.3404 - val_accuracy: 0.7231
# Epoch 78/100
# 2/2 [==============================] - 9s 5s/step - loss: 3.0548 - accuracy: 0.9180 - val_loss: 3.3322 - val_accuracy: 0.7231
# Epoch 79/100
# 2/2 [==============================] - 9s 5s/step - loss: 3.0409 - accuracy: 0.9141 - val_loss: 3.3349 - val_accuracy: 0.7385
# Epoch 80/100
# 2/2 [==============================] - 9s 5s/step - loss: 3.0305 - accuracy: 0.9102 - val_loss: 3.3405 - val_accuracy: 0.7538
# Epoch 81/100
# 2/2 [==============================] - 10s 5s/step - loss: 3.0184 - accuracy: 0.9102 - val_loss: 3.3161 - val_accuracy: 0.7231
# Epoch 82/100
# 2/2 [==============================] - 9s 5s/step - loss: 3.0045 - accuracy: 0.9180 - val_loss: 3.2960 - val_accuracy: 0.7231
# Epoch 83/100
# 2/2 [==============================] - 9s 5s/step - loss: 2.9954 - accuracy: 0.9258 - val_loss: 3.2976 - val_accuracy: 0.7231
# Epoch 84/100
# 2/2 [==============================] - 10s 5s/step - loss: 2.9879 - accuracy: 0.9258 - val_loss: 3.3119 - val_accuracy: 0.7692
# Epoch 85/100
# 2/2 [==============================] - 9s 5s/step - loss: 2.9704 - accuracy: 0.9258 - val_loss: 3.2891 - val_accuracy: 0.7231
# Epoch 86/100
# 2/2 [==============================] - 9s 5s/step - loss: 2.9628 - accuracy: 0.9297 - val_loss: 3.2852 - val_accuracy: 0.7231
# Epoch 87/100
# 2/2 [==============================] - 9s 5s/step - loss: 2.9527 - accuracy: 0.9219 - val_loss: 3.2856 - val_accuracy: 0.7692
# Epoch 88/100
# 2/2 [==============================] - 10s 5s/step - loss: 2.9383 - accuracy: 0.9297 - val_loss: 3.2798 - val_accuracy: 0.7385
# Epoch 89/100
# 2/2 [==============================] - 9s 5s/step - loss: 2.9310 - accuracy: 0.9297 - val_loss: 3.2721 - val_accuracy: 0.7692
# Epoch 90/100
# 2/2 [==============================] - 9s 5s/step - loss: 2.9294 - accuracy: 0.9180 - val_loss: 3.2747 - val_accuracy: 0.7385
# Epoch 91/100
# 2/2 [==============================] - 10s 5s/step - loss: 2.9243 - accuracy: 0.9297 - val_loss: 3.2432 - val_accuracy: 0.7231
# Epoch 92/100
# 2/2 [==============================] - 9s 5s/step - loss: 2.8920 - accuracy: 0.9258 - val_loss: 3.2860 - val_accuracy: 0.7231
# Epoch 93/100
# 2/2 [==============================] - 9s 5s/step - loss: 2.8935 - accuracy: 0.9375 - val_loss: 3.2596 - val_accuracy: 0.7846
# Epoch 94/100
# 2/2 [==============================] - 9s 5s/step - loss: 2.8753 - accuracy: 0.9297 - val_loss: 3.2399 - val_accuracy: 0.7538
# Epoch 95/100
# 2/2 [==============================] - 10s 5s/step - loss: 2.8639 - accuracy: 0.9375 - val_loss: 3.2370 - val_accuracy: 0.7538
# Epoch 96/100
# 2/2 [==============================] - 9s 5s/step - loss: 2.8591 - accuracy: 0.9375 - val_loss: 3.2422 - val_accuracy: 0.7846
# Epoch 97/100
# 2/2 [==============================] - 10s 5s/step - loss: 2.8409 - accuracy: 0.9336 - val_loss: 3.2357 - val_accuracy: 0.7538
# Epoch 98/100
# 2/2 [==============================] - 10s 5s/step - loss: 2.8436 - accuracy: 0.9414 - val_loss: 3.2055 - val_accuracy: 0.7538
# Epoch 99/100
# 2/2 [==============================] - 9s 5s/step - loss: 2.8180 - accuracy: 0.9414 - val_loss: 3.2077 - val_accuracy: 0.7538
# Epoch 100/100
# 2/2 [==============================] - 9s 5s/step - loss: 2.8130 - accuracy: 0.9375 - val_loss: 3.2402 - val_accuracy: 0.7538

# %% [markdown]
# Now we will train our model on 100 epochs and a batch size of 128. You can try using more number of epochs to increase accuracy. During each epochs we can see how the model is performing by viewing the training and validation accuracy.

# %%
# Plot the training history
plt.figure(figsize=(12, 5))
plt.plot(history.history['accuracy'], color='r')
plt.plot(history.history['val_accuracy'], color='b')
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epochs')
plt.legend(['train', 'val'])

plt.show()

# %% [markdown]
# Here we analyse how the model is learning with each epoch in terms of accuracy.

# %%
Y_pred = model.predict(X_test)
score = model.evaluate(X_test, Y_test)
print('Accuracy over the test set: \n ', round((score[1]*100), 2), '%')
# Out:
# 2/2 [==============================] - 0s 39ms/step - loss: 3.4896 - accuracy: 0.7222
# Accuracy over the test set:
#   72.22 %

# %% [markdown]
# We will use predict function to make predictions using this model also we are finding out the accuracy on the test set.

# %%
# Plotting image to compare
plt.imshow(X_test[1,:,:,:])
plt.show()

# Finding max value from predition list and comaparing original value vs predicted
print("Originally : ",labels['breed'][np.argmax(Y_test[1])])
print("Predicted : ",labels['breed'][np.argmax(Y_pred[1])])
# Out:
# Originally :  scottish_deerhound
# Predicted :  scottish_deerhound

# %% [markdown]
# Here you can see image with its original and predicted label.

# %% [markdown]
# ## Conclusion:

# %% [markdown]
# We started with downloading the dataset creating the model and finding out the predictions using the model. We can optimize different hyper parameters in order to tune this model for a higher accuracy. This model can be used to predict different breeds of dogs which can be further used by different NGO's working on saving animals and for educational purposes also.
